# %%
import pandas as pd
import numpy as np
import os

# %%
PropsOfPropsRace = pd.read_csv('/Users/tracy/Documents/GitHub/STAT5702_NYC_Employment_Analysis/D3_files/data/PreprocessedData/PropsOfPropsRace.csv') 
PropsOfPropsRace.sort_values(by=['White'], ascending=False)
# Out:
#                                            Occupation     Asian     White  \
# 6                                               Legal  0.209782  0.507601
# 8      Arts, design, entertainment, sports, and media  0.238447  0.501985
# 4                  Life, physical, and social science  0.372460  0.394326
# 0                                          Management  0.262722  0.387828
# 7                    Education, training, and library  0.182677  0.369850
# 1                   Business and financial operations  0.354056  0.344397
# 3                        Architecture and engineering  0.373799  0.340562
# 2                           Computer and mathematical  0.442226  0.310413
# 9   Health diagnosing and treating practitioners a...  0.406858  0.259061
# 17                                  Sales and related  0.291389  0.255603
# 20                        Construction and extraction  0.154568  0.227761
# 18                  Office and administrative support  0.217450  0.225229
# ...

# %%
PropsOfPropsWhite = PropsOfPropsRace.iloc[:,[0,2]]
PropsOfPropsWhite.to_csv("/Users/tracy/Documents/GitHub/STAT5702_NYC_Employment_Analysis/D3_files/data/PreprocessedData/PropsOfPropsWhite.csv",index = False)

PropsOfPropsAsian = PropsOfPropsRace.iloc[:,[0,2]]
PropsOfPropsAsian.to_csv("/Users/tracy/Documents/GitHub/STAT5702_NYC_Employment_Analysis/D3_files/data/PreprocessedData/PropsOfPropsAsian.csv",index = False)

PropsOfPropsHispanic = PropsOfPropsRace.iloc[:,[0,2]]
PropsOfPropsHispanic.to_csv("/Users/tracy/Documents/GitHub/STAT5702_NYC_Employment_Analysis/D3_files/data/PreprocessedData/PropsOfPropsHispanic.csv",index = False)

PropsOfPropsBlack = PropsOfPropsRace.iloc[:,[0,2]]
PropsOfPropsBlack.to_csv("/Users/tracy/Documents/GitHub/STAT5702_NYC_Employment_Analysis/D3_files/data/PreprocessedData/PropsOfPropsBlack.csv",index = False)

# %%
filename = '/Users/tracy/Documents/GitHub/STAT5702_NYC_Employment_Analysis/D3_files/data/PreprocessedData/PropsOfPropsWhite.csv'
with open(filename) as f:
    s = f.read() + '\n' # add trailing new line character

print(repr(s))
# Out:
# 'Occupation,White\nManagement,0.387827896061693\nBusiness and financial operations,0.344396535451777\nComputer and mathematical,0.310413159871412\nArchitecture and engineering,0.340561803168321\n"Life, physical, and social science",0.394325572556175\nCommunity and social service,0.206032230490246\nLegal,0.507600775058515\n"Education, training, and library",0.36984951850708203\n"Arts, design, entertainment, sports, and media",0.5019850411000271\nHealth diagnosing and treating practitioners and other technical,0.259060692815113\nHealth technologists and technicians,0.155579772131681\nHealthcare support,0.10240463696427\nFire fighting and prevention,0.154696290810648\nLaw enforcement workers,0.216421868545472\nFood preparation and serving related,0.16821664935657502\nBuilding and grounds cleaning and maintenance,0.158990324526523\nPersonal care and service,0.163490600884364\nSales and related,0.255602630424827\nOffice and administrative support,0.225229126085057\n"Farming, fishing, and 
# ...
