# %%
import pandas as pd
import numpy as np
import os

# %%
Asian_Alone2010 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2010_Asian_Alone.csv")
Asian_Alone2011 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2011_Asian_Alone.csv")
Asian_Alone2012 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2012_Asian_Alone.csv")
Asian_Alone2013 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2013_Asian_Alone.csv")
Asian_Alone2014 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2014_Asian_Alone.csv")
Asian_Alone2015 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2015_Asian_Alone.csv")
Asian_Alone2016 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2016_Asian_Alone.csv")
Asian_Alone2017 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2017_Asian_Alone.csv")
Asian_Alone2018 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2018_Asian_Alone.csv")
Asian_Alone2019 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Asian_Alone/2019_Asian_Alone.csv")

# %%
Asian_Alone2010["year"] = Asian_Alone2010.apply(lambda x: 2010, axis=1)
Asian_Alone2010["race"] = Asian_Alone2010.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2010["Label"] = Asian_Alone2010["Label"].str.strip()
Asian_Alone2010["Gender"] = ""
Asian_Alone2010["Gender"][0] = "Total"
Asian_Alone2010["Gender"][1] = "Total Male"
Asian_Alone2010["Gender"][2:37] = "Male"
Asian_Alone2010["Gender"][37] = "Total Female"
Asian_Alone2010["Gender"][38:73] = "Female"


Asian_Alone2011["year"] = Asian_Alone2011.apply(lambda x: 2011, axis=1)
Asian_Alone2011["race"] = Asian_Alone2011.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2011["Label"] = Asian_Alone2011["Label"].str.strip()
Asian_Alone2011["Gender"] = ""
Asian_Alone2011["Gender"][0] = "Total"
Asian_Alone2011["Gender"][1] = "Total Male"
Asian_Alone2011["Gender"][2:37] = "Male"
Asian_Alone2011["Gender"][37] = "Total Female"
Asian_Alone2011["Gender"][38:73] = "Female"


Asian_Alone2012["year"] = Asian_Alone2012.apply(lambda x: 2012, axis=1)
Asian_Alone2012["race"] = Asian_Alone2012.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2012["Label"] = Asian_Alone2012["Label"].str.strip()
Asian_Alone2012["Gender"] = ""
Asian_Alone2012["Gender"][0] = "Total"
Asian_Alone2012["Gender"][1] = "Total Male"
Asian_Alone2012["Gender"][2:37] = "Male"
Asian_Alone2012["Gender"][37] = "Total Female"
Asian_Alone2012["Gender"][38:73] = "Female"


Asian_Alone2013["year"] = Asian_Alone2013.apply(lambda x: 2013, axis=1)
Asian_Alone2013["race"] = Asian_Alone2013.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2013["Label"] = Asian_Alone2013["Label"].str.strip()
Asian_Alone2013["Gender"] = ""
Asian_Alone2013["Gender"][0] = "Total"
Asian_Alone2013["Gender"][1] = "Total Male"
Asian_Alone2013["Gender"][2:37] = "Male"
Asian_Alone2013["Gender"][37] = "Total Female"
Asian_Alone2013["Gender"][38:73] = "Female"


Asian_Alone2014["year"] = Asian_Alone2014.apply(lambda x: 2014, axis=1)
Asian_Alone2014["race"] = Asian_Alone2014.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2014["Label"] = Asian_Alone2014["Label"].str.strip()
Asian_Alone2014["Gender"] = ""
Asian_Alone2014["Gender"][0] = "Total"
Asian_Alone2014["Gender"][1] = "Total Male"
Asian_Alone2014["Gender"][2:37] = "Male"
Asian_Alone2014["Gender"][37] = "Total Female"
Asian_Alone2014["Gender"][38:73] = "Female"


Asian_Alone2015["year"] = Asian_Alone2015.apply(lambda x: 2015, axis=1)
Asian_Alone2015["race"] = Asian_Alone2015.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2015["Label"] = Asian_Alone2015["Label"].str.strip()
Asian_Alone2015["Gender"] = ""
Asian_Alone2015["Gender"][0] = "Total"
Asian_Alone2015["Gender"][1] = "Total Male"
Asian_Alone2015["Gender"][2:37] = "Male"
Asian_Alone2015["Gender"][37] = "Total Female"
Asian_Alone2015["Gender"][38:73] = "Female"


Asian_Alone2016["year"] = Asian_Alone2016.apply(lambda x: 2016, axis=1)
Asian_Alone2016["race"] = Asian_Alone2016.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2016["Label"] = Asian_Alone2016["Label"].str.strip()
Asian_Alone2016["Gender"] = ""
Asian_Alone2016["Gender"][0] = "Total"
Asian_Alone2016["Gender"][1] = "Total Male"
Asian_Alone2016["Gender"][2:37] = "Male"
Asian_Alone2016["Gender"][37] = "Total Female"
Asian_Alone2016["Gender"][38:73] = "Female"


Asian_Alone2017["year"] = Asian_Alone2017.apply(lambda x: 2017, axis=1)
Asian_Alone2017["race"] = Asian_Alone2017.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2017["Label"] = Asian_Alone2017["Label"].str.strip()
Asian_Alone2017["Gender"] = ""
Asian_Alone2017["Gender"][0] = "Total"
Asian_Alone2017["Gender"][1] = "Total Male"
Asian_Alone2017["Gender"][2:37] = "Male"
Asian_Alone2017["Gender"][37] = "Total Female"
Asian_Alone2017["Gender"][38:73] = "Female"


Asian_Alone2018["year"] = Asian_Alone2018.apply(lambda x: 2018, axis=1)
Asian_Alone2018["race"] = Asian_Alone2018.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2018["Label"] = Asian_Alone2018["Label"].str.strip()
Asian_Alone2018["Gender"] = ""
Asian_Alone2018["Gender"][0] = "Total"
Asian_Alone2018["Gender"][1] = "Total Male"
Asian_Alone2018["Gender"][2:37] = "Male"
Asian_Alone2018["Gender"][37] = "Total Female"
Asian_Alone2018["Gender"][38:73] = "Female"


Asian_Alone2019["year"] = Asian_Alone2019.apply(lambda x: 2019, axis=1)
Asian_Alone2019["race"] = Asian_Alone2019.apply(lambda x: "Asian Alone", axis=1)
Asian_Alone2019["Label"] = Asian_Alone2019["Label"].str.strip()
Asian_Alone2019["Gender"] = ""
Asian_Alone2019["Gender"][0] = "Total"
Asian_Alone2019["Gender"][1] = "Total Male"
Asian_Alone2019["Gender"][2:37] = "Male"
Asian_Alone2019["Gender"][37] = "Total Female"
Asian_Alone2019["Gender"][38:73] = "Female"

frames = [Asian_Alone2010,Asian_Alone2011,Asian_Alone2012,Asian_Alone2013,Asian_Alone2014,Asian_Alone2015,Asian_Alone2016,Asian_Alone2017,Asian_Alone2018,Asian_Alone2019]
Asian_Alone = pd.concat(frames)
Asian_Alone = Asian_Alone.rename(columns={"Bronx County, New York / Estimate":"Bronx County, New York",
                                          "Kings County, New York / Estimate":"Kings County, New York",
                                          "New York County, New York / Estimate":"New York County, New York",
                                          "Queens County, New York / Estimate":"Queens County, New York",
                                          "Richmond County, New York / Estimate":"Richmond County, New York"})

Asian_Alone
# Out:
# <ipython-input-3-3f2412da74ba>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_Alone2010["Gender"][0] = "Total"
# <ipython-input-3-3f2412da74ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_Alone2010["Gender"][1] = "Total Male"
# <ipython-input-3-3f2412da74ba>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Asian_Alone2010["Gender"][2:37] = "Male"
# ...

# %%
BLACK_OR_AFRICAN_AMERICAN_ALONE2010 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2010_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2011 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2011_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2012 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2012_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2013 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2013_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2014 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2014_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2015 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2015_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2016 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2016_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2017 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2017_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2018 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2018_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")
BLACK_OR_AFRICAN_AMERICAN_ALONE2019 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/BLACK_OR_AFRICAN_AMERICAN_ALONE/2019_BLACK_OR_AFRICAN_AMERICAN_ALONE.csv")

# %%
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2010.apply(lambda x: 2010, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2010.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2011["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2011.apply(lambda x: 2011, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2011.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2011["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2012["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2012.apply(lambda x: 2012, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2012.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2012["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2013["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2013.apply(lambda x: 2013, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2013.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2013["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2014["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2014.apply(lambda x: 2014, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2014.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2014["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2015["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2015.apply(lambda x: 2015, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2015.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2015["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2016["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2016.apply(lambda x: 2016, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2016.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2016["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2017["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2017.apply(lambda x: 2017, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2017.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2017["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2018["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2018.apply(lambda x: 2018, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2018.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2018["Gender"][38:73] = "Female"


BLACK_OR_AFRICAN_AMERICAN_ALONE2019["year"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2019.apply(lambda x: 2019, axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["race"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2019.apply(lambda x: "BLACK OR AFRICAN AMERICAN ALONE", axis=1)
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Label"] = BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Label"].str.strip()
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Gender"] = ""
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Gender"][0] = "Total"
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Gender"][1] = "Total Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Gender"][2:37] = "Male"
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Gender"][37] = "Total Female"
BLACK_OR_AFRICAN_AMERICAN_ALONE2019["Gender"][38:73] = "Female"


frames = [BLACK_OR_AFRICAN_AMERICAN_ALONE2010,BLACK_OR_AFRICAN_AMERICAN_ALONE2011,BLACK_OR_AFRICAN_AMERICAN_ALONE2012,
          BLACK_OR_AFRICAN_AMERICAN_ALONE2013,BLACK_OR_AFRICAN_AMERICAN_ALONE2014,BLACK_OR_AFRICAN_AMERICAN_ALONE2015,
          BLACK_OR_AFRICAN_AMERICAN_ALONE2016,BLACK_OR_AFRICAN_AMERICAN_ALONE2017,BLACK_OR_AFRICAN_AMERICAN_ALONE2018,
          BLACK_OR_AFRICAN_AMERICAN_ALONE2019]
BLACK_OR_AFRICAN_AMERICAN_ALONE = pd.concat(frames)
BLACK_OR_AFRICAN_AMERICAN_ALONE = BLACK_OR_AFRICAN_AMERICAN_ALONE.rename(columns={"Bronx County, New York / Estimate":"Bronx County, New York",
                                                                                  "Kings County, New York / Estimate":"Kings County, New York",
                                                                                  "New York County, New York / Estimate":"New York County, New York",
                                                                                  "Queens County, New York / Estimate":"Queens County, New York",
                                                                                  "Richmond County, New York / Estimate":"Richmond County, New York"})
BLACK_OR_AFRICAN_AMERICAN_ALONE
# Out:
# <ipython-input-5-39e78f494262>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"][0] = "Total"
# <ipython-input-5-39e78f494262>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BLACK_OR_AFRICAN_AMERICAN_ALONE2010["Gender"][1] = "Total Male"
# <ipython-input-5-39e78f494262>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
HISPANIC_OR_LATINO2010 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2010_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2011 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2011_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2012 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2012_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2013 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2013_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2014 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2014_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2015 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2015_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2016 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2016_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2017 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2017_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2018 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2018_HISPANIC_OR_LATINO.csv")
HISPANIC_OR_LATINO2019 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/HISPANIC_OR_LATINO/2019_HISPANIC_OR_LATINO.csv")

# %%
HISPANIC_OR_LATINO2010["year"] = HISPANIC_OR_LATINO2010.apply(lambda x: 2010, axis=1)
HISPANIC_OR_LATINO2010["race"] = HISPANIC_OR_LATINO2010.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2010["Label"] = HISPANIC_OR_LATINO2010["Label"].str.strip()
HISPANIC_OR_LATINO2010["Gender"] = ""
HISPANIC_OR_LATINO2010["Gender"][0] = "Total"
HISPANIC_OR_LATINO2010["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2010["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2010["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2010["Gender"][38:73] = "Female"



HISPANIC_OR_LATINO2011["year"] = HISPANIC_OR_LATINO2011.apply(lambda x: 2011, axis=1)
HISPANIC_OR_LATINO2011["race"] = HISPANIC_OR_LATINO2011.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2011["Label"] = HISPANIC_OR_LATINO2011["Label"].str.strip()
HISPANIC_OR_LATINO2011["Gender"] = ""
HISPANIC_OR_LATINO2011["Gender"][0] = "Total"
HISPANIC_OR_LATINO2011["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2011["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2011["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2011["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2012["year"] = HISPANIC_OR_LATINO2012.apply(lambda x: 2012, axis=1)
HISPANIC_OR_LATINO2012["race"] = HISPANIC_OR_LATINO2012.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2012["Label"] = HISPANIC_OR_LATINO2012["Label"].str.strip()
HISPANIC_OR_LATINO2012["Gender"] = ""
HISPANIC_OR_LATINO2012["Gender"][0] = "Total"
HISPANIC_OR_LATINO2012["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2012["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2012["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2012["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2013["year"] = HISPANIC_OR_LATINO2013.apply(lambda x: 2013, axis=1)
HISPANIC_OR_LATINO2013["race"] = HISPANIC_OR_LATINO2013.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2013["Label"] = HISPANIC_OR_LATINO2013["Label"].str.strip()
HISPANIC_OR_LATINO2013["Gender"] = ""
HISPANIC_OR_LATINO2013["Gender"][0] = "Total"
HISPANIC_OR_LATINO2013["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2013["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2013["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2013["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2014["year"] = HISPANIC_OR_LATINO2014.apply(lambda x: 2014, axis=1)
HISPANIC_OR_LATINO2014["race"] = HISPANIC_OR_LATINO2014.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2014["Label"] = HISPANIC_OR_LATINO2014["Label"].str.strip()
HISPANIC_OR_LATINO2014["Gender"] = ""
HISPANIC_OR_LATINO2014["Gender"][0] = "Total"
HISPANIC_OR_LATINO2014["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2014["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2014["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2014["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2015["year"] = HISPANIC_OR_LATINO2015.apply(lambda x: 2015, axis=1)
HISPANIC_OR_LATINO2015["race"] = HISPANIC_OR_LATINO2015.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2015["Label"] = HISPANIC_OR_LATINO2015["Label"].str.strip()
HISPANIC_OR_LATINO2015["Gender"] = ""
HISPANIC_OR_LATINO2015["Gender"][0] = "Total"
HISPANIC_OR_LATINO2015["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2015["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2015["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2015["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2016["year"] = HISPANIC_OR_LATINO2016.apply(lambda x: 2016, axis=1)
HISPANIC_OR_LATINO2016["race"] = HISPANIC_OR_LATINO2016.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2016["Label"] = HISPANIC_OR_LATINO2016["Label"].str.strip()
HISPANIC_OR_LATINO2016["Gender"] = ""
HISPANIC_OR_LATINO2016["Gender"][0] = "Total"
HISPANIC_OR_LATINO2016["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2016["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2016["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2016["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2017["year"] = HISPANIC_OR_LATINO2017.apply(lambda x: 2017, axis=1)
HISPANIC_OR_LATINO2017["race"] = HISPANIC_OR_LATINO2017.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2017["Label"] = HISPANIC_OR_LATINO2017["Label"].str.strip()
HISPANIC_OR_LATINO2017["Gender"] = ""
HISPANIC_OR_LATINO2017["Gender"][0] = "Total"
HISPANIC_OR_LATINO2017["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2017["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2017["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2017["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2018["year"] = HISPANIC_OR_LATINO2018.apply(lambda x: 2018, axis=1)
HISPANIC_OR_LATINO2018["race"] = HISPANIC_OR_LATINO2018.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2018["Label"] = HISPANIC_OR_LATINO2018["Label"].str.strip()
HISPANIC_OR_LATINO2018["Gender"] = ""
HISPANIC_OR_LATINO2018["Gender"][0] = "Total"
HISPANIC_OR_LATINO2018["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2018["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2018["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2018["Gender"][38:73] = "Female"


HISPANIC_OR_LATINO2019["year"] = HISPANIC_OR_LATINO2019.apply(lambda x: 2019, axis=1)
HISPANIC_OR_LATINO2019["race"] = HISPANIC_OR_LATINO2019.apply(lambda x: "HISPANIC OR LATINO", axis=1)
HISPANIC_OR_LATINO2019["Label"] = HISPANIC_OR_LATINO2019["Label"].str.strip()
HISPANIC_OR_LATINO2019["Gender"] = ""
HISPANIC_OR_LATINO2019["Gender"][0] = "Total"
HISPANIC_OR_LATINO2019["Gender"][1] = "Total Male"
HISPANIC_OR_LATINO2019["Gender"][2:37] = "Male"
HISPANIC_OR_LATINO2019["Gender"][37] = "Total Female"
HISPANIC_OR_LATINO2019["Gender"][38:73] = "Female"


frames = [HISPANIC_OR_LATINO2010,HISPANIC_OR_LATINO2011,HISPANIC_OR_LATINO2012,
          HISPANIC_OR_LATINO2013,HISPANIC_OR_LATINO2014,HISPANIC_OR_LATINO2015,
          HISPANIC_OR_LATINO2016,HISPANIC_OR_LATINO2017,HISPANIC_OR_LATINO2018,
          HISPANIC_OR_LATINO2019]
HISPANIC_OR_LATINO = pd.concat(frames)
HISPANIC_OR_LATINO = HISPANIC_OR_LATINO.rename(columns={"Bronx County, New York / Estimate":"Bronx County, New York",
                                                                                  "Kings County, New York / Estimate":"Kings County, New York",
                                                                                  "New York County, New York / Estimate":"New York County, New York",
                                                                                  "Queens County, New York / Estimate":"Queens County, New York",
                                                                                  "Richmond County, New York / Estimate":"Richmond County, New York"})
HISPANIC_OR_LATINO
# Out:
# <ipython-input-7-24c5ddedd447>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HISPANIC_OR_LATINO2010["Gender"][0] = "Total"
# <ipython-input-7-24c5ddedd447>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HISPANIC_OR_LATINO2010["Gender"][1] = "Total Male"
# <ipython-input-7-24c5ddedd447>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HISPANIC_OR_LATINO2010["Gender"][2:37] = "Male"
# ...

# %%
SomeOtherRaceAlone2010 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2010_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2011 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2011_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2012 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2012_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2013 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2013_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2014 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2014_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2015 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2015_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2016 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2016_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2017 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2017_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2018 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2018_SomeOtherRaceAlone.csv")
SomeOtherRaceAlone2019 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Some_Other_Race_Alone/2019_SomeOtherRaceAlone.csv")

# %%
SomeOtherRaceAlone2010["year"] = SomeOtherRaceAlone2010.apply(lambda x: 2010, axis=1)
SomeOtherRaceAlone2010["race"] = SomeOtherRaceAlone2010.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2010["Label"] = SomeOtherRaceAlone2010["Label"].str.strip()
SomeOtherRaceAlone2010["Gender"] = ""
SomeOtherRaceAlone2010["Gender"][0] = "Total"
SomeOtherRaceAlone2010["Gender"][1] = "Total Male"
SomeOtherRaceAlone2010["Gender"][2:37] = "Male"
SomeOtherRaceAlone2010["Gender"][37] = "Total Female"
SomeOtherRaceAlone2010["Gender"][38:73] = "Female"


SomeOtherRaceAlone2011["year"] = SomeOtherRaceAlone2011.apply(lambda x: 2011, axis=1)
SomeOtherRaceAlone2011["race"] = SomeOtherRaceAlone2011.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2011["Label"] = SomeOtherRaceAlone2011["Label"].str.strip()
SomeOtherRaceAlone2011["Gender"] = ""
SomeOtherRaceAlone2011["Gender"][0] = "Total"
SomeOtherRaceAlone2011["Gender"][1] = "Total Male"
SomeOtherRaceAlone2011["Gender"][2:37] = "Male"
SomeOtherRaceAlone2011["Gender"][37] = "Total Female"
SomeOtherRaceAlone2011["Gender"][38:73] = "Female"


SomeOtherRaceAlone2012["year"] = SomeOtherRaceAlone2012.apply(lambda x: 2012, axis=1)
SomeOtherRaceAlone2012["race"] = SomeOtherRaceAlone2012.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2012["Label"] = SomeOtherRaceAlone2012["Label"].str.strip()
SomeOtherRaceAlone2012["Gender"] = ""
SomeOtherRaceAlone2012["Gender"][0] = "Total"
SomeOtherRaceAlone2012["Gender"][1] = "Total Male"
SomeOtherRaceAlone2012["Gender"][2:37] = "Male"
SomeOtherRaceAlone2012["Gender"][37] = "Total Female"
SomeOtherRaceAlone2012["Gender"][38:73] = "Female"


SomeOtherRaceAlone2013["year"] = SomeOtherRaceAlone2013.apply(lambda x: 2013, axis=1)
SomeOtherRaceAlone2013["race"] = SomeOtherRaceAlone2013.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2013["Label"] = SomeOtherRaceAlone2013["Label"].str.strip()
SomeOtherRaceAlone2013["Gender"] = ""
SomeOtherRaceAlone2013["Gender"][0] = "Total"
SomeOtherRaceAlone2013["Gender"][1] = "Total Male"
SomeOtherRaceAlone2013["Gender"][2:37] = "Male"
SomeOtherRaceAlone2013["Gender"][37] = "Total Female"
SomeOtherRaceAlone2013["Gender"][38:73] = "Female"


SomeOtherRaceAlone2014["year"] = SomeOtherRaceAlone2014.apply(lambda x: 2014, axis=1)
SomeOtherRaceAlone2014["race"] = SomeOtherRaceAlone2014.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2014["Label"] = SomeOtherRaceAlone2014["Label"].str.strip()
SomeOtherRaceAlone2014["Gender"] = ""
SomeOtherRaceAlone2014["Gender"][0] = "Total"
SomeOtherRaceAlone2014["Gender"][1] = "Total Male"
SomeOtherRaceAlone2014["Gender"][2:37] = "Male"
SomeOtherRaceAlone2014["Gender"][37] = "Total Female"
SomeOtherRaceAlone2014["Gender"][38:73] = "Female"


SomeOtherRaceAlone2015["year"] = SomeOtherRaceAlone2015.apply(lambda x: 2015, axis=1)
SomeOtherRaceAlone2015["race"] = SomeOtherRaceAlone2015.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2015["Label"] = SomeOtherRaceAlone2015["Label"].str.strip()
SomeOtherRaceAlone2015["Gender"] = ""
SomeOtherRaceAlone2015["Gender"][0] = "Total"
SomeOtherRaceAlone2015["Gender"][1] = "Total Male"
SomeOtherRaceAlone2015["Gender"][2:37] = "Male"
SomeOtherRaceAlone2015["Gender"][37] = "Total Female"
SomeOtherRaceAlone2015["Gender"][38:73] = "Female"


SomeOtherRaceAlone2016["year"] = SomeOtherRaceAlone2016.apply(lambda x: 2016, axis=1)
SomeOtherRaceAlone2016["race"] = SomeOtherRaceAlone2016.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2016["Label"] = SomeOtherRaceAlone2016["Label"].str.strip()
SomeOtherRaceAlone2016["Gender"] = ""
SomeOtherRaceAlone2016["Gender"][0] = "Total"
SomeOtherRaceAlone2016["Gender"][1] = "Total Male"
SomeOtherRaceAlone2016["Gender"][2:37] = "Male"
SomeOtherRaceAlone2016["Gender"][37] = "Total Female"
SomeOtherRaceAlone2016["Gender"][38:73] = "Female"


SomeOtherRaceAlone2017["year"] = SomeOtherRaceAlone2017.apply(lambda x: 2017, axis=1)
SomeOtherRaceAlone2017["race"] = SomeOtherRaceAlone2017.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2017["Label"] = SomeOtherRaceAlone2017["Label"].str.strip()
SomeOtherRaceAlone2017["Gender"] = ""
SomeOtherRaceAlone2017["Gender"][0] = "Total"
SomeOtherRaceAlone2017["Gender"][1] = "Total Male"
SomeOtherRaceAlone2017["Gender"][2:37] = "Male"
SomeOtherRaceAlone2017["Gender"][37] = "Total Female"
SomeOtherRaceAlone2017["Gender"][38:73] = "Female"


SomeOtherRaceAlone2018["year"] = SomeOtherRaceAlone2018.apply(lambda x: 2018, axis=1)
SomeOtherRaceAlone2018["race"] = SomeOtherRaceAlone2018.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2018["Label"] = SomeOtherRaceAlone2018["Label"].str.strip()
SomeOtherRaceAlone2018["Gender"] = ""
SomeOtherRaceAlone2018["Gender"][0] = "Total"
SomeOtherRaceAlone2018["Gender"][1] = "Total Male"
SomeOtherRaceAlone2018["Gender"][2:37] = "Male"
SomeOtherRaceAlone2018["Gender"][37] = "Total Female"
SomeOtherRaceAlone2018["Gender"][38:73] = "Female"


SomeOtherRaceAlone2019["year"] = SomeOtherRaceAlone2019.apply(lambda x: 2019, axis=1)
SomeOtherRaceAlone2019["race"] = SomeOtherRaceAlone2019.apply(lambda x: "Some Other Race Alone", axis=1)
SomeOtherRaceAlone2019["Label"] = SomeOtherRaceAlone2019["Label"].str.strip()
SomeOtherRaceAlone2019["Gender"] = ""
SomeOtherRaceAlone2019["Gender"][0] = "Total"
SomeOtherRaceAlone2019["Gender"][1] = "Total Male"
SomeOtherRaceAlone2019["Gender"][2:37] = "Male"
SomeOtherRaceAlone2019["Gender"][37] = "Total Female"
SomeOtherRaceAlone2019["Gender"][38:73] = "Female"


frames = [SomeOtherRaceAlone2010,SomeOtherRaceAlone2011,SomeOtherRaceAlone2012,
          SomeOtherRaceAlone2013,SomeOtherRaceAlone2014,SomeOtherRaceAlone2015,
          SomeOtherRaceAlone2016,SomeOtherRaceAlone2017,SomeOtherRaceAlone2018,
          SomeOtherRaceAlone2019]
SomeOtherRaceAlone = pd.concat(frames)
SomeOtherRaceAlone = SomeOtherRaceAlone.rename(columns={"Bronx County, New York / Estimate":"Bronx County, New York",
                                                                                  "Kings County, New York / Estimate":"Kings County, New York",
                                                                                  "New York County, New York / Estimate":"New York County, New York",
                                                                                  "Queens County, New York / Estimate":"Queens County, New York",
                                                                                  "Richmond County, New York / Estimate":"Richmond County, New York"})
SomeOtherRaceAlone
# Out:
# <ipython-input-9-0f0ea4590316>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SomeOtherRaceAlone2010["Gender"][0] = "Total"
# <ipython-input-9-0f0ea4590316>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SomeOtherRaceAlone2010["Gender"][1] = "Total Male"
# <ipython-input-9-0f0ea4590316>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SomeOtherRaceAlone2010["Gender"][2:37] = "Male"
# ...

# %%
Two_or_More_Races2010 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2010_Two_or_More_Races.csv")
Two_or_More_Races2011 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2011_Two_or_More_Races.csv")
Two_or_More_Races2012 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2012_Two_or_More_Races.csv")
Two_or_More_Races2013 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2013_Two_or_More_Races.csv")
Two_or_More_Races2014 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2014_Two_or_More_Races.csv")
Two_or_More_Races2015 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2015_Two_or_More_Races.csv")
Two_or_More_Races2016 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2016_Two_or_More_Races.csv")
Two_or_More_Races2017 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2017_Two_or_More_Races.csv")
Two_or_More_Races2018 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2018_Two_or_More_Races.csv")
Two_or_More_Races2019 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/Two_or_More_Races/2019_Two_or_More_Races.csv")

# %%
Two_or_More_Races2010["year"] = Two_or_More_Races2010.apply(lambda x: 2010, axis=1)
Two_or_More_Races2010["race"] = Two_or_More_Races2010.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2010["Label"] = Two_or_More_Races2010["Label"].str.strip()
Two_or_More_Races2010["Gender"] = ""
Two_or_More_Races2010["Gender"][0] = "Total"
Two_or_More_Races2010["Gender"][1] = "Total Male"
Two_or_More_Races2010["Gender"][2:37] = "Male"
Two_or_More_Races2010["Gender"][37] = "Total Female"
Two_or_More_Races2010["Gender"][38:73] = "Female"


Two_or_More_Races2011["year"] = Two_or_More_Races2011.apply(lambda x: 2011, axis=1)
Two_or_More_Races2011["race"] = Two_or_More_Races2011.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2011["Label"] = Two_or_More_Races2011["Label"].str.strip()
Two_or_More_Races2011["Gender"] = ""
Two_or_More_Races2011["Gender"][0] = "Total"
Two_or_More_Races2011["Gender"][1] = "Total Male"
Two_or_More_Races2011["Gender"][2:37] = "Male"
Two_or_More_Races2011["Gender"][37] = "Total Female"
Two_or_More_Races2011["Gender"][38:73] = "Female"


Two_or_More_Races2012["year"] = Two_or_More_Races2012.apply(lambda x: 2012, axis=1)
Two_or_More_Races2012["race"] = Two_or_More_Races2012.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2012["Label"] = Two_or_More_Races2012["Label"].str.strip()
Two_or_More_Races2012["Gender"] = ""
Two_or_More_Races2012["Gender"][0] = "Total"
Two_or_More_Races2012["Gender"][1] = "Total Male"
Two_or_More_Races2012["Gender"][2:37] = "Male"
Two_or_More_Races2012["Gender"][37] = "Total Female"
Two_or_More_Races2012["Gender"][38:73] = "Female"


Two_or_More_Races2013["year"] = Two_or_More_Races2013.apply(lambda x: 2013, axis=1)
Two_or_More_Races2013["race"] = Two_or_More_Races2013.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2013["Label"] = Two_or_More_Races2013["Label"].str.strip()
Two_or_More_Races2013["Gender"] = ""
Two_or_More_Races2013["Gender"][0] = "Total"
Two_or_More_Races2013["Gender"][1] = "Total Male"
Two_or_More_Races2013["Gender"][2:37] = "Male"
Two_or_More_Races2013["Gender"][37] = "Total Female"
Two_or_More_Races2013["Gender"][38:73] = "Female"


Two_or_More_Races2014["year"] = Two_or_More_Races2014.apply(lambda x: 2014, axis=1)
Two_or_More_Races2014["race"] = Two_or_More_Races2014.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2014["Label"] = Two_or_More_Races2014["Label"].str.strip()
Two_or_More_Races2014["Gender"] = ""
Two_or_More_Races2014["Gender"][0] = "Total"
Two_or_More_Races2014["Gender"][1] = "Total Male"
Two_or_More_Races2014["Gender"][2:37] = "Male"
Two_or_More_Races2014["Gender"][37] = "Total Female"
Two_or_More_Races2014["Gender"][38:73] = "Female"


Two_or_More_Races2015["year"] = Two_or_More_Races2015.apply(lambda x: 2015, axis=1)
Two_or_More_Races2015["race"] = Two_or_More_Races2015.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2015["Label"] = Two_or_More_Races2015["Label"].str.strip()
Two_or_More_Races2015["Gender"] = ""
Two_or_More_Races2015["Gender"][0] = "Total"
Two_or_More_Races2015["Gender"][1] = "Total Male"
Two_or_More_Races2015["Gender"][2:37] = "Male"
Two_or_More_Races2015["Gender"][37] = "Total Female"
Two_or_More_Races2015["Gender"][38:73] = "Female"


Two_or_More_Races2016["year"] = Two_or_More_Races2016.apply(lambda x: 2016, axis=1)
Two_or_More_Races2016["race"] = Two_or_More_Races2016.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2016["Label"] = Two_or_More_Races2016["Label"].str.strip()
Two_or_More_Races2016["Gender"] = ""
Two_or_More_Races2016["Gender"][0] = "Total"
Two_or_More_Races2016["Gender"][1] = "Total Male"
Two_or_More_Races2016["Gender"][2:37] = "Male"
Two_or_More_Races2016["Gender"][37] = "Total Female"
Two_or_More_Races2016["Gender"][38:73] = "Female"


Two_or_More_Races2017["year"] = Two_or_More_Races2017.apply(lambda x: 2017, axis=1)
Two_or_More_Races2017["race"] = Two_or_More_Races2017.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2017["Label"] = Two_or_More_Races2017["Label"].str.strip()
Two_or_More_Races2017["Gender"] = ""
Two_or_More_Races2017["Gender"][0] = "Total"
Two_or_More_Races2017["Gender"][1] = "Total Male"
Two_or_More_Races2017["Gender"][2:37] = "Male"
Two_or_More_Races2017["Gender"][37] = "Total Female"
Two_or_More_Races2017["Gender"][38:73] = "Female"


Two_or_More_Races2018["year"] = Two_or_More_Races2018.apply(lambda x: 2018, axis=1)
Two_or_More_Races2018["race"] = Two_or_More_Races2018.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2018["Label"] = Two_or_More_Races2018["Label"].str.strip()
Two_or_More_Races2018["Gender"] = ""
Two_or_More_Races2018["Gender"][0] = "Total"
Two_or_More_Races2018["Gender"][1] = "Total Male"
Two_or_More_Races2018["Gender"][2:37] = "Male"
Two_or_More_Races2018["Gender"][37] = "Total Female"
Two_or_More_Races2018["Gender"][38:73] = "Female"


Two_or_More_Races2019["year"] = Two_or_More_Races2019.apply(lambda x: 2019, axis=1)
Two_or_More_Races2019["race"] = Two_or_More_Races2019.apply(lambda x: "Two or More Races", axis=1)
Two_or_More_Races2019["Label"] = Two_or_More_Races2019["Label"].str.strip()
Two_or_More_Races2019["Gender"] = ""
Two_or_More_Races2019["Gender"][0] = "Total"
Two_or_More_Races2019["Gender"][1] = "Total Male"
Two_or_More_Races2019["Gender"][2:37] = "Male"
Two_or_More_Races2019["Gender"][37] = "Total Female"
Two_or_More_Races2019["Gender"][38:73] = "Female"


frames = [Two_or_More_Races2010,Two_or_More_Races2011,Two_or_More_Races2012,
          Two_or_More_Races2013,Two_or_More_Races2014,Two_or_More_Races2015,
          Two_or_More_Races2016,Two_or_More_Races2017,Two_or_More_Races2018,
          Two_or_More_Races2019]
Two_or_More_Races = pd.concat(frames)
Two_or_More_Races = Two_or_More_Races.rename(columns={"Bronx County, New York / Estimate":"Bronx County, New York",
                                                                                  "Kings County, New York / Estimate":"Kings County, New York",
                                                                                  "New York County, New York / Estimate":"New York County, New York",
                                                                                  "Queens County, New York / Estimate":"Queens County, New York",
                                                                                  "Richmond County, New York / Estimate":"Richmond County, New York"})
Two_or_More_Races
# Out:
# <ipython-input-11-1e3ca0d4927c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Two_or_More_Races2010["Gender"][0] = "Total"
# <ipython-input-11-1e3ca0d4927c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Two_or_More_Races2010["Gender"][1] = "Total Male"
# <ipython-input-11-1e3ca0d4927c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Two_or_More_Races2010["Gender"][2:37] = "Male"
# ...

# %%
White_Alone2010 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2010_White_Alone.csv")
White_Alone2011 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2011_White_Alone.csv")
White_Alone2012 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2012_White_Alone.csv")
White_Alone2013 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2013_White_Alone.csv")
White_Alone2014 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2014_White_Alone.csv")
White_Alone2015 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2015_White_Alone.csv")
White_Alone2016 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2016_White_Alone.csv")
White_Alone2017 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2017_White_Alone.csv")
White_Alone2018 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2018_White_Alone.csv")
White_Alone2019 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/White_Alone/2019_White_Alone.csv")

# %%
White_Alone2010["year"] = White_Alone2010.apply(lambda x: 2010, axis=1)
White_Alone2010["race"] = White_Alone2010.apply(lambda x: "White Alone", axis=1)
White_Alone2010["Label"] = White_Alone2010["Label"].str.strip()
White_Alone2010["Gender"] = ""
White_Alone2010["Gender"][0] = "Total"
White_Alone2010["Gender"][1] = "Total Male"
White_Alone2010["Gender"][2:37] = "Male"
White_Alone2010["Gender"][37] = "Total Female"
White_Alone2010["Gender"][38:73] = "Female"


White_Alone2011["year"] = White_Alone2011.apply(lambda x: 2011, axis=1)
White_Alone2011["race"] = White_Alone2011.apply(lambda x: "White Alone", axis=1)
White_Alone2011["Label"] = White_Alone2011["Label"].str.strip()
White_Alone2011["Gender"] = ""
White_Alone2011["Gender"][0] = "Total"
White_Alone2011["Gender"][1] = "Total Male"
White_Alone2011["Gender"][2:37] = "Male"
White_Alone2011["Gender"][37] = "Total Female"
White_Alone2011["Gender"][38:73] = "Female"


White_Alone2012["year"] = White_Alone2012.apply(lambda x: 2012, axis=1)
White_Alone2012["race"] = White_Alone2012.apply(lambda x: "White Alone", axis=1)
White_Alone2012["Label"] = White_Alone2012["Label"].str.strip()
White_Alone2012["Gender"] = ""
White_Alone2012["Gender"][0] = "Total"
White_Alone2012["Gender"][1] = "Total Male"
White_Alone2012["Gender"][2:37] = "Male"
White_Alone2012["Gender"][37] = "Total Female"
White_Alone2012["Gender"][38:73] = "Female"


White_Alone2013["year"] = White_Alone2013.apply(lambda x: 2013, axis=1)
White_Alone2013["race"] = White_Alone2013.apply(lambda x: "White Alone", axis=1)
White_Alone2013["Label"] = White_Alone2013["Label"].str.strip()
White_Alone2013["Gender"] = ""
White_Alone2013["Gender"][0] = "Total"
White_Alone2013["Gender"][1] = "Total Male"
White_Alone2013["Gender"][2:37] = "Male"
White_Alone2013["Gender"][37] = "Total Female"
White_Alone2013["Gender"][38:73] = "Female"


White_Alone2014["year"] = White_Alone2014.apply(lambda x: 2014, axis=1)
White_Alone2014["race"] = White_Alone2014.apply(lambda x: "White Alone", axis=1)
White_Alone2014["Label"] = White_Alone2014["Label"].str.strip()
White_Alone2014["Gender"] = ""
White_Alone2014["Gender"][0] = "Total"
White_Alone2014["Gender"][1] = "Total Male"
White_Alone2014["Gender"][2:37] = "Male"
White_Alone2014["Gender"][37] = "Total Female"
White_Alone2014["Gender"][38:73] = "Female"


White_Alone2015["year"] = White_Alone2015.apply(lambda x: 2015, axis=1)
White_Alone2015["race"] = White_Alone2015.apply(lambda x: "White Alone", axis=1)
White_Alone2015["Label"] = White_Alone2015["Label"].str.strip()
White_Alone2015["Gender"] = ""
White_Alone2015["Gender"][0] = "Total"
White_Alone2015["Gender"][1] = "Total Male"
White_Alone2015["Gender"][2:37] = "Male"
White_Alone2015["Gender"][37] = "Total Female"
White_Alone2015["Gender"][38:73] = "Female"


White_Alone2016["year"] = White_Alone2016.apply(lambda x: 2016, axis=1)
White_Alone2016["race"] = White_Alone2016.apply(lambda x: "White Alone", axis=1)
White_Alone2016["Label"] = White_Alone2016["Label"].str.strip()
White_Alone2016["Gender"] = ""
White_Alone2016["Gender"][0] = "Total"
White_Alone2016["Gender"][1] = "Total Male"
White_Alone2016["Gender"][2:37] = "Male"
White_Alone2016["Gender"][37] = "Total Female"
White_Alone2016["Gender"][38:73] = "Female"


White_Alone2017["year"] = White_Alone2017.apply(lambda x: 2017, axis=1)
White_Alone2017["race"] = White_Alone2017.apply(lambda x: "White Alone", axis=1)
White_Alone2017["Label"] = White_Alone2017["Label"].str.strip()
White_Alone2017["Gender"] = ""
White_Alone2017["Gender"][0] = "Total"
White_Alone2017["Gender"][1] = "Total Male"
White_Alone2017["Gender"][2:37] = "Male"
White_Alone2017["Gender"][37] = "Total Female"
White_Alone2017["Gender"][38:73] = "Female"


White_Alone2018["year"] = White_Alone2018.apply(lambda x: 2018, axis=1)
White_Alone2018["race"] = White_Alone2018.apply(lambda x: "White Alone", axis=1)
White_Alone2018["Label"] = White_Alone2018["Label"].str.strip()
White_Alone2018["Gender"] = ""
White_Alone2018["Gender"][0] = "Total"
White_Alone2018["Gender"][1] = "Total Male"
White_Alone2018["Gender"][2:37] = "Male"
White_Alone2018["Gender"][37] = "Total Female"
White_Alone2018["Gender"][38:73] = "Female"


White_Alone2019["year"] = White_Alone2019.apply(lambda x: 2019, axis=1)
White_Alone2019["race"] = White_Alone2019.apply(lambda x: "White Alone", axis=1)
White_Alone2019["Label"] = White_Alone2019["Label"].str.strip()
White_Alone2019["Gender"] = ""
White_Alone2019["Gender"][0] = "Total"
White_Alone2019["Gender"][1] = "Total Male"
White_Alone2019["Gender"][2:37] = "Male"
White_Alone2019["Gender"][37] = "Total Female"
White_Alone2019["Gender"][38:73] = "Female"

frames = [White_Alone2010,White_Alone2011,White_Alone2012,
          White_Alone2013,White_Alone2014,White_Alone2015,
          White_Alone2016,White_Alone2017,White_Alone2018,
          White_Alone2019]
White_Alone = pd.concat(frames)
White_Alone = White_Alone.rename(columns={"Bronx County, New York / Estimate":"Bronx County, New York",
                                                                                  "Kings County, New York / Estimate":"Kings County, New York",
                                                                                  "New York County, New York / Estimate":"New York County, New York",
                                                                                  "Queens County, New York / Estimate":"Queens County, New York",
                                                                                  "Richmond County, New York / Estimate":"Richmond County, New York"})
White_Alone
# Out:
# <ipython-input-13-f24b730c17d9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   White_Alone2010["Gender"][0] = "Total"
# <ipython-input-13-f24b730c17d9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   White_Alone2010["Gender"][1] = "Total Male"
# <ipython-input-13-f24b730c17d9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   White_Alone2010["Gender"][2:37] = "Male"
# ...

# %%
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2010_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2011_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2012_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2013_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2014_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2015_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2016_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2017_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2018_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019 = pd.read_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/RawData/occupation_sex_race_year_gender_county/WHITE_ALONE_NOT_HISPANIC_OR_LATINO/2019_WHITE_ALONE_NOT_HISPANIC_OR_LATINO.csv")

# %%
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010.apply(lambda x: 2010, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011.apply(lambda x: 2011, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012.apply(lambda x: 2012, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013.apply(lambda x: 2013, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014.apply(lambda x: 2014, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015.apply(lambda x: 2015, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016.apply(lambda x: 2016, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017.apply(lambda x: 2017, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018.apply(lambda x: 2018, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018["Gender"][38:73] = "Female"


WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["year"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019.apply(lambda x: 2019, axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["race"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019.apply(lambda x: "WHITE ALONE NOT HISPANIC OR LATINO", axis=1)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Label"] = WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Label"].str.strip()
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Gender"] = ""
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Gender"][0] = "Total"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Gender"][1] = "Total Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Gender"][2:37] = "Male"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Gender"][37] = "Total Female"
WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019["Gender"][38:73] = "Female"


frames = [WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010,WHITE_ALONE_NOT_HISPANIC_OR_LATINO2011,WHITE_ALONE_NOT_HISPANIC_OR_LATINO2012,
          WHITE_ALONE_NOT_HISPANIC_OR_LATINO2013,WHITE_ALONE_NOT_HISPANIC_OR_LATINO2014,WHITE_ALONE_NOT_HISPANIC_OR_LATINO2015,
          WHITE_ALONE_NOT_HISPANIC_OR_LATINO2016,WHITE_ALONE_NOT_HISPANIC_OR_LATINO2017,WHITE_ALONE_NOT_HISPANIC_OR_LATINO2018,
          WHITE_ALONE_NOT_HISPANIC_OR_LATINO2019]
WHITE_ALONE_NOT_HISPANIC_OR_LATINO = pd.concat(frames)
WHITE_ALONE_NOT_HISPANIC_OR_LATINO = WHITE_ALONE_NOT_HISPANIC_OR_LATINO.rename(columns={"Bronx County, New York / Estimate":"Bronx County, New York",
                                                                                  "Kings County, New York / Estimate":"Kings County, New York",
                                                                                  "New York County, New York / Estimate":"New York County, New York",
                                                                                  "Queens County, New York / Estimate":"Queens County, New York",
                                                                                  "Richmond County, New York / Estimate":"Richmond County, New York"})
WHITE_ALONE_NOT_HISPANIC_OR_LATINO
# Out:
# <ipython-input-15-24042cd87c7f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"][0] = "Total"
# <ipython-input-15-24042cd87c7f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WHITE_ALONE_NOT_HISPANIC_OR_LATINO2010["Gender"][1] = "Total Male"
# <ipython-input-15-24042cd87c7f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
frames = [Asian_Alone, BLACK_OR_AFRICAN_AMERICAN_ALONE, HISPANIC_OR_LATINO, SomeOtherRaceAlone,Two_or_More_Races,
          White_Alone,WHITE_ALONE_NOT_HISPANIC_OR_LATINO]
numemp = pd.concat(frames)

numemp = numemp.rename(columns = {"Label":"Occupations"})

numemp['Occupations'] = numemp['Occupations'].replace(['Firefighting and prevention, and other protective service workers including supervisors'],'Fire fighting and prevention, and other protective service workers including supervisors')
numemp['Occupations'] = numemp['Occupations'].replace(['Educational instruction, and library occupations'],'Education, training, and library occupations')


numemp_occupations = numemp[(numemp['Occupations'] == 'Management occupations')|
       (numemp['Occupations'] == 'Business and financial operations occupations')|
       (numemp['Occupations'] == 'Computer and mathematical occupations')|
       (numemp['Occupations'] == 'Architecture and engineering occupations')|
       (numemp['Occupations'] == 'Life, physical, and social science occupations')|
       (numemp['Occupations'] == 'Community and social service occupations')|
       (numemp['Occupations'] == 'Legal occupations')|
       (numemp['Occupations'] == 'Education, training, and library occupations')|
       (numemp['Occupations'] == 'Arts, design, entertainment, sports, and media occupations')|
       (numemp['Occupations'] == 'Health diagnosing and treating practitioners and other technical occupations')|
       (numemp['Occupations'] == 'Health technologists and technicians')|
       (numemp['Occupations'] == 'Healthcare support occupations')|
       (numemp['Occupations'] == 'Fire fighting and prevention, and other protective service workers including supervisors')|
       (numemp['Occupations'] == 'Law enforcement workers including supervisors')|
       (numemp['Occupations'] == 'Food preparation and serving related occupations')|
       (numemp['Occupations'] == 'Building and grounds cleaning and maintenance occupations')|
       (numemp['Occupations'] == 'Personal care and service occupations')|
       (numemp['Occupations'] == 'Sales and related occupations')|
       (numemp['Occupations'] == 'Office and administrative support occupations')|
       (numemp['Occupations'] == 'Farming, fishing, and forestry occupations')|
       (numemp['Occupations'] == 'Construction and extraction occupations')|
       (numemp['Occupations'] == 'Installation, maintenance, and repair occupations')|
       (numemp['Occupations'] == 'Production occupations')|
       (numemp['Occupations'] == 'Transportation occupations')|
       (numemp['Occupations'] == 'Material moving occupations')]

numemp_sum = numemp[(numemp['Occupations'] == 'Total:')|
       (numemp['Occupations'] == 'Male:')|
       (numemp['Occupations'] == 'Female:')]

numemp_sum
# Out:
#    Occupations  Bronx County, New York  Kings County, New York  \
# 0       Total:                 22160.0                  121664
# 1        Male:                 12283.0                   66638
# 37     Female:                  9877.0                   55026
# 0       Total:                 19823.0                  125204
# 1        Male:                 11265.0                   66752
# ..         ...                     ...                     ...
# 1        Male:                 27080.0                  251027
# 37     Female:                 24654.0                  232514
# 0       Total:                 51845.0                  482826
# 1        Male:                 29171.0                  250713
# 37     Female:                 22674.0                  232113
#
#     New York County, New York  Queens County, New York  \
# 0                     98647.0                   248187
# 1                     44989.0                   135390
# ...

# %%
numemp_occupations.to_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/DataPreprocessing/Data/NumEmp/numemp_02.csv")
numemp_sum.to_csv(r"/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/DataPreprocessing/Data/NumEmp/numemp_sum.csv")
