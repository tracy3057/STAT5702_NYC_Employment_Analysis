# %%
import numpy as np
import pandas as pd

# %%
GenderData = pd.read_csv('C:/Users/eabea/Dropbox/Documents/STAT W5702/Project/STAT5702_NYC_Employment_Analysis/DataPreprocessing/Data/Preprocess_ClevelandDotPlot/gendercleveland.csv')
RaceData = pd.read_csv('C:/Users/eabea/Dropbox/Documents/STAT W5702/Project/STAT5702_NYC_Employment_Analysis/DataPreprocessing/Data/Preprocess_ClevelandDotPlot/OccupationByRace.csv')

# %%
RaceData.style
# Out:
# <style  type="text/css" >
# </style><table id="T_2c6af222_2cb3_11eb_ab3b_00d8613a0075" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unnamed: 0</th>        <th class="col_heading level0 col1" >Occupations</th>        <th class="col_heading level0 col2" >Asian_Alone</th>        <th class="col_heading level0 col3" >Black_or_African_American_Alone</th>        <th class="col_heading level0 col4" >Hispanic_or_Latino</th>        <th class="col_heading level0 col5" >Some_Other_Race_Alone</th>        <th class="col_heading level0 col6" >Two_or_More_Races</th>        <th class="col_heading level0 col7" >White_Alone</th>        <th class="col_heading level0 col8" >White_Alone_not_Hispanic_or_Latino</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2c6af222_2cb3_11eb_ab3b_00d8613a0075level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
GenderData.style
# Out:
# <style  type="text/css" >
# </style><table id="T_2fe944b8_2cb3_11eb_9bf0_00d8613a0075" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Occupations</th>        <th class="col_heading level0 col1" >NumEmps</th>        <th class="col_heading level0 col2" >Gender</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2fe944b8_2cb3_11eb_9bf0_00d8613a0075level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2fe944b8_2cb3_11eb_9bf0_00d8613a0075row0_col0" class="data row0 col0" >Management occupations</td>
#                         <td id="T_2fe944b8_2cb3_11eb_9bf0_00d8613a0075row0_col1" class="data row0 col1" >290732.800000</td>
#                         <td id="T_2fe944b8_2cb3_11eb_9bf0_00d8613a0075row0_col2" class="data row0 col2" >Female</td>
#             </tr>
#             <tr>
# ...
