# %%
import pandas as pd
import numpy as np
import os

# %%
Data = pd.read_csv('/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/DataPreprocessing/Data/NumEmp/numemp_01.csv')
Data
#Data = pd.read_csv('C:/Users/eabea/Dropbox/Documents/STAT W5702/Project/STAT5702_NYC_Employment_Analysis/RawData/OccupationVSotherVariables/DetailedAnalysisOnSex+Occupation+Race/race.csv')
# Out:
#       Unnamed: 0                                        Occupations  \
# 0              4                             Management occupations
# 1              5      Business and financial operations occupations
# 2              7              Computer and mathematical occupations
# 3              8           Architecture and engineering occupations
# 4              9     Life, physical, and social science occupations
# ...          ...                                                ...
# 3495          67            Construction and extraction occupations
# 3496          68  Installation, maintenance, and repair occupations
# 3497          70                             Production occupations
# 3498          71                         Transportation occupations
# 3499          72                        Material moving occupations
#
#       Bronx County, New York  Kings County, New York  \
# 0                      458.0                    3330
# 1                      645.0                    2069
# 2                      544.0                    2635
# 3                      271.0                     872
# 4                       87.0                     143
# ...                      ...                     ...
# 3495                     0.0                     187
# 3496                     0.0                     121
# 3497                   220.0                    1995
# 3498                   285.0                     587
# 3499                   169.0                     657
#
#       New York County, New York  Queens County, New York  \
# 0                        7144.0                    11371
# 1                        5636.0                     8411
# 2                        3904.0                     6097
# 3                         402.0                     1773
# 4                        1359.0                      724
# ...                         ...                      ...
# 3495                      497.0                      209
# 3496                       17.0                       72
# 3497                     1075.0                     1547
# 3498                      160.0                     1181
# 3499                      955.0                      498
#
#       Richmond County, New York  year                                race  \
# 0                         719.0  2010                         Asian Alone
# 1                         700.0  2010                         Asian Alone
# 2                         472.0  2010                         Asian Alone
# 3                         298.0  2010                         Asian Alone
# 4                          50.0  2010                         Asian Alone
# ...                         ...   ...                                 ...
# 3495                      142.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3496                      485.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3497                      179.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3498                      294.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3499                      651.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
#
#       Gender
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 3495  Female
# 3496  Female
# 3497  Female
# 3498  Female
# 3499  Female
#
# [3500 rows x 10 columns]

# %%
cols = ['Unnamed: 0', 'Label', 'Bronx County, New York', 'Kings County, New York', 'New York County, New York', 'Queens County, New York', 'Richmond County, New York', 'race', 'year']

try:
    Data = Data[cols]
    Data = Data.drop(columns = 'Unnamed: 0')
except KeyError:
    pass

Data.fillna(0,inplace = True)
Data
# Out:
#       Unnamed: 0                                        Occupations  \
# 0              4                             Management occupations
# 1              5      Business and financial operations occupations
# 2              7              Computer and mathematical occupations
# 3              8           Architecture and engineering occupations
# 4              9     Life, physical, and social science occupations
# ...          ...                                                ...
# 3495          67            Construction and extraction occupations
# 3496          68  Installation, maintenance, and repair occupations
# 3497          70                             Production occupations
# 3498          71                         Transportation occupations
# 3499          72                        Material moving occupations
#
#       Bronx County, New York  Kings County, New York  \
# 0                      458.0                    3330
# 1                      645.0                    2069
# 2                      544.0                    2635
# 3                      271.0                     872
# 4                       87.0                     143
# ...                      ...                     ...
# 3495                     0.0                     187
# 3496                     0.0                     121
# 3497                   220.0                    1995
# 3498                   285.0                     587
# 3499                   169.0                     657
#
#       New York County, New York  Queens County, New York  \
# 0                        7144.0                    11371
# 1                        5636.0                     8411
# 2                        3904.0                     6097
# 3                         402.0                     1773
# 4                        1359.0                      724
# ...                         ...                      ...
# 3495                      497.0                      209
# 3496                       17.0                       72
# 3497                     1075.0                     1547
# 3498                      160.0                     1181
# 3499                      955.0                      498
#
#       Richmond County, New York  year                                race  \
# 0                         719.0  2010                         Asian Alone
# 1                         700.0  2010                         Asian Alone
# 2                         472.0  2010                         Asian Alone
# 3                         298.0  2010                         Asian Alone
# 4                          50.0  2010                         Asian Alone
# ...                         ...   ...                                 ...
# 3495                      142.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3496                      485.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3497                      179.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3498                      294.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
# 3499                      651.0  2019  WHITE ALONE NOT HISPANIC OR LATINO
#
#       Gender
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 3495  Female
# 3496  Female
# 3497  Female
# 3498  Female
# 3499  Female
#
# [3500 rows x 10 columns]

# %%
Years = [i for i in range(2010,2020)]
OccupationsByYear = []

for year in Years:
    Occupations = {'Management occupations':0,
               'Business and financial operations occupations':0,
               'Computer and mathematical occupations':0,
               'Architecture and engineering occupations':0,
               'Life, physical, and social science occupations':0,
               'Community and social service occupations':0,
               'Legal occupations':0,
               'Education, training, and library occupations':0,
               'Arts, design, entertainment, sports, and media occupations':0,
               'Health diagnosing and treating practitioners and other technical occupations':0,
               'Health technologists and technicians':0,
               'Healthcare support occupations':0,
               'Fire fighting and prevention, and other protective service workers including supervisors':0,
               'Law enforcement workers including supervisors':0,
               'Food preparation and serving related occupations':0,
               'Building and grounds cleaning and maintenance occupations':0,
               'Personal care and service occupations':0,
               'Sales and related occupations':0,
               'Office and administrative support occupations':0,
               'Farming, fishing, and forestry occupations':0,
               'Construction and extraction occupations':0,
               'Installation, maintenance, and repair occupations':0,
               'Production occupations':0,
               'Transportation occupations':0,
               'Material moving occupations':0}
    YearData = Data[Data['year'] == year]
    for i in range(YearData.shape[0]):
        for key in Occupations.keys():           
            if key in YearData.iloc[i][0] and sum(YearData.iloc[i][x] for x in range(1,6)) != np.nan:
                Occupations[key] += sum(YearData.iloc[i][x] for x in range(1,6)) 
    
    Occupations = pd.DataFrame.from_dict(Occupations,orient='index',columns=['NumEmps'])
    Occupations.insert(loc=0,column = 'Occupations',value = Occupations.index)
    Occupations.reset_index(drop=True,inplace=True)
    Occupations['year'] = year
    OccupationsByYear.append(Occupations)


OccupationsByYear = pd.concat(OccupationsByYear)
OccupationsByYear
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-61284acf9d2e> in <module>
#      31     for i in range(YearData.shape[0]):
#      32         for key in Occupations.keys():
# ---> 33             if key in YearData.iloc[i][0] and sum(YearData.iloc[i][x] for x in range(1,6)) != np.nan:
#      34                 Occupations[key] += sum(YearData.iloc[i][x] for x in range(1,6))
#      35
#
# TypeError: argument of type 'numpy.int64' is not iterable

# %%
#OccupationsByYear.to_csv(os.path.join('C:/Users/eabea/Dropbox/Documents/STAT W5702/Project/STAT5702_NYC_Employment_Analysis/DataPreprocessing/Data/Preprocess_ClevelandDotPlot/','yearly_cleveland.csv'),index=False)
OccupationsByYear.to_csv('/Users/tracy/Desktop/STAT5702_NYC_Employment_Analysis/DataPreprocessing/Data/NumEmp/yearly_cleveland.csv')
